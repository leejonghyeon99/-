# %% [markdown]
# <a href="https://colab.research.google.com/github/leejonghyeon99/python_stu/blob/main/01_matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Matplotlib
# https://matplotlib.org/ <br>
#
# <img src="https://matplotlib.org/_static/logo_light.svg" width="300px"/>

# %%
# 파이썬의 자료(DataFrame, Series 등..)을  차트(chart) 나 플롯(plot) 으로
# 시각화(visualization) 하는 모듈

# Matplotlib는 다음과 같은 정형화된 차트나 플롯 이외에도
# 저수준 api를 사용한 다양한 시각화 기능을 제공한다.

# 라인 플롯(line plot)
# 스캐터 플롯(scatter plot)
# 컨투어 플롯(contour plot)
# 서피스 플롯(surface plot)
# 바 차트(bar chart)
# 히스토그램(histogram)
# 박스 플롯(box plot)

# ※ "맷플롯립" 라이브러리 로 읽힌다.

# %% [markdown]
# ## matplotlib 시각화 예제 갤러리
# https://matplotlib.org/stable/gallery/index.html

# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

# %%
np.__version__
pd.__version__
matplotlib.__version__
# Out:
# '3.7.1'

# %% [markdown]
# # Plot

# %% [markdown]
# ## Line plot
# 가장 간단한 플롯,  선을 그리는 라인 플롯<br>
# 데이터가 시간, 순서 등에 따라 어떻게 변화하는지 보여주기 위한 용도
#
# http://Matplotlib.org/api/pyplot_api.html#Matplotlib.pyplot.plot

# %% [markdown]
# ### array -> line plot 그리기

# %%
arr = np.array([10, 30, 14, 20])

# %%
plt.plot(arr)
# ↓ index 는 x 축으로 value 는 y 축으로 표현된다
# plt.show()

# %%
# 2차원 array 의 경우는?
arr = np.array([
    [10, 30, 14, 20],
    [20, 50, 33, 10],
    [30, 20, 5, 0]
])

# %%
plt.plot(arr)

# %%
x = np.arange(0, 1, 0.01)
y = x ** 2

plt.plot(x, y)

# %% [markdown]
# ### Series -> line plot 그리기

# %%
s = pd.Series(np.random.randn(10).cumsum(), index=np.arange(0,100, 10))
s
# Out:
# 0     1.695469
# 10    1.187978
# 20    1.097041
# 30    1.185266
# 40    1.630547
# 50    3.120789
# 60    3.739658
# 70    3.650907
# 80    4.126656
# 90    3.590003
# dtype: float64

# %%
plt.plot(s)

# index 는 x 축 값으로
# value 는 y 축 값으로 line plot 형성

# %%
s.plot()
# Out:
# <Axes: >

# %% [markdown]
# ### DataFrame -> line plot 그리기

# %%
df = pd.DataFrame(np.random.randn(10, 4).cumsum(axis=0),
                  columns=["A", "B", "C", "D"],
                  index=np.arange(0, 100, 10))
df
# Out:
#            A         B         C         D
# 0   2.389198  0.427969 -0.447756  0.511956
# 10  1.710043 -1.000635  0.642611  1.808015
# 20  1.749000 -1.211492  0.619317  1.001861
# 30  2.239078 -1.014463  0.380594  2.305099
# 40  3.157807 -0.497955  0.807269  3.498220
# 50  5.709094  0.091318 -0.913160  4.097078
# 60  6.068731 -0.061329 -1.657208  2.758995
# 70  6.715719  1.009350 -2.275519  1.679504
# 80  5.420406  2.127682 -0.775272  2.641394
# 90  6.924127  1.966664  0.916034  1.575069

# %%
df.plot()

# index 는 x 축
# values 는 y 값으로 표현
# 컬럼명이 범례(legend) 표시
# Out:
# <Axes: >

# %%
plt.plot(df)

# %%
df['B'].plot()
# Out:
# <Axes: >

# %%
df[['B', 'A']].plot()
# Out:
# <Axes: >

# %% [markdown]
# # Bar Plot (막대)

# %%
s2 = pd.Series(np.random.rand(16), index=list("abcdefghijklmnop"))
s2
# Out:
# a    0.566287
# b    0.305905
# c    0.080946
# d    0.846994
# e    0.143436
# f    0.447189
# g    0.762730
# h    0.046560
# i    0.417276
# j    0.635998
# k    0.570955
# l    0.894638
# m    0.137303
# n    0.140138
# o    0.015374
# p    0.446687
# dtype: float64

# %%
s2.plot()
# Out:
# <Axes: >

# %%
s2.plot(kind = 'bar')
# Out:
# <Axes: >

# %%
s2.plot(kind = 'barh')
# Out:
# <Axes: >

# %%
# DataFrame - > bar plot

# %%
df2 = pd.DataFrame(np.random.rand(6, 4),
                   index=["one", "two", "three", "four", "five", "six"],
                   columns=pd.Index(["A", "B", "C", "D"], name="Genus"))
df2
# Out:
# Genus         A         B         C         D
# one    0.018680  0.376923  0.293712  0.614407
# two    0.023170  0.979727  0.286188  0.685529
# three  0.172953  0.637228  0.210399  0.744277
# four   0.594491  0.343924  0.550948  0.574439
# five   0.668198  0.240276  0.165369  0.635595
# six    0.012126  0.537511  0.212036  0.723799

# %%
df2.plot(kind = 'barh')
# Out:
# <Axes: >

# %%
df2.plot(kind = 'barh', stacked=True)
# Out:
# <Axes: >

# %% [markdown]
# ## Histogram
# 도수분포표의 하나, 가로축이 계급, 세로축이 도수

# %%
# histogram은 index가 필요없다.
s3 = pd.Series(np.random.normal(0, 1, size=200))
s3
# Out:
# 0     -1.322317
# 1     -0.146662
# 2     -1.969559
# 3     -1.216529
# 4      1.474194
#          ...
# 195    0.362912
# 196   -0.095321
# 197    0.561041
# 198    0.111044
# 199   -0.169468
# Length: 200, dtype: float64

# %%
s3.hist()
# Out:
# <Axes: >

# %%
# x 축 구간의 개수를 bin 이라 한다

s3.hist(bins=50)
# Out:
# <Axes: >

# %%
s3.hist(bins=200)
# Out:
# <Axes: >

# %% [markdown]
# ## Scatter plot 그리기
# 산점도 : 산점도의 경우에는 서로 다른 두 개의 독립변수에 대해 두 변수가 어떤 관계가 있는지 살펴보기 위해 사용된다.

# %%
x1 = np.random.normal(1, 1, size=(100, 1))
x1
# Out:
# array([[-0.66224923],
#        [ 2.13643778],
#        [-0.36527048],
#        [ 1.48702073],
#        [ 2.13173429],
#        [ 0.93197176],
#        [ 1.56619879],
#        [ 2.21542053],
#        [ 1.43925889],
#        [-0.23197526],
#        [ 2.26886412],
#        [ 2.00246371],
#        [ 2.63937289],
#        [ 0.22887644],
#        [ 0.94111748],
#        [ 1.65588818],
#        [ 0.47079985],
#        [ 1.02426492],
#        [ 0.42807861],
#        [ 0.84119607],
#        [ 1.07243975],
#        [ 1.46507794],
#        [ 2.21983355],
#        [ 0.38550866],
#        [-0.07154456],
#        [ 0.54025175],
#        [ 0.68142818],
#        [ 2.05519399],
#        [ 0.66841712],
#        [ 2.91624463],
#        [ 0.7221893 ],
#        [ 2.52863474],
#        [ 1.60954055],
#        [ 1.77380424],
#        [-0.50892544],
#        [ 0.67038236],
#        [ 1.01504212],
#        [-0.74286216],
#        [ 0.46914599],
#        [ 0.20900319],
#        [ 2.79671352],
# ...

# %%
x2 = np.random.normal(-2, 4, size=(100, 1))
x2
# Out:
# array([[ -0.59420249],
#        [  0.24759909],
#        [  0.45048602],
#        [ -4.9925951 ],
#        [ -2.05845582],
#        [-10.67152858],
#        [ -2.01948822],
#        [ -5.11517351],
#        [ -2.86105758],
#        [  2.27450772],
#        [  4.72425748],
#        [-10.56459177],
#        [ -1.51042154],
#        [  1.20044178],
#        [ -0.14353114],
#        [ -0.33752658],
#        [ -0.23424188],
#        [  7.44948939],
#        [ -4.9418513 ],
#        [  0.73023335],
#        [  2.99987251],
#        [  1.35277594],
#        [ -1.67656009],
#        [ -5.78423643],
#        [ -5.44022871],
#        [ -0.78993993],
#        [ -7.66466028],
#        [ -5.4098514 ],
#        [ -4.02957346],
#        [ -6.75534098],
#        [ -2.76238983],
#        [ -4.70489503],
#        [ -2.73946043],
#        [ -2.6666918 ],
#        [ -1.8568069 ],
#        [ -1.21552466],
#        [ -2.40804174],
#        [ -0.83795479],
#        [ -4.4301578 ],
#        [ -6.54201866],
# ...

# %%
X = np.concatenate((x1, x2), axis=1)
X
# Out:
# array([[ -0.66224923,  -0.59420249],
#        [  2.13643778,   0.24759909],
#        [ -0.36527048,   0.45048602],
#        [  1.48702073,  -4.9925951 ],
#        [  2.13173429,  -2.05845582],
#        [  0.93197176, -10.67152858],
#        [  1.56619879,  -2.01948822],
#        [  2.21542053,  -5.11517351],
#        [  1.43925889,  -2.86105758],
#        [ -0.23197526,   2.27450772],
#        [  2.26886412,   4.72425748],
#        [  2.00246371, -10.56459177],
#        [  2.63937289,  -1.51042154],
#        [  0.22887644,   1.20044178],
#        [  0.94111748,  -0.14353114],
#        [  1.65588818,  -0.33752658],
#        [  0.47079985,  -0.23424188],
#        [  1.02426492,   7.44948939],
#        [  0.42807861,  -4.9418513 ],
#        [  0.84119607,   0.73023335],
#        [  1.07243975,   2.99987251],
#        [  1.46507794,   1.35277594],
#        [  2.21983355,  -1.67656009],
#        [  0.38550866,  -5.78423643],
#        [ -0.07154456,  -5.44022871],
# ...

# %%
df3 = pd.DataFrame(X, columns = ['x1', 'x2'])
df3
# Out:
#           x1        x2
# 0  -0.662249 -0.594202
# 1   2.136438  0.247599
# 2  -0.365270  0.450486
# 3   1.487021 -4.992595
# 4   2.131734 -2.058456
# ..       ...       ...
# 95  1.881737 -5.240677
# 96  1.409383  0.286095
# 97  0.508053 -4.536741
# 98  0.675139 -3.039017
# 99  1.969913 -0.198412
#
# [100 rows x 2 columns]

# %%
plt.scatter(df3['x1'], df3['x2'])  # x1이 x축, x2 가 y축

# %% [markdown]
# # 여러 Line 그리기

# %%
x = np.arange(0, 1, 0.01)

plt.plot(x)

# %%
plt.plot(
    x, x, "r--",  # plot1
    x, x ** 2, 'k--', # plot2
    x, x ** 3, 'b--', # plot3
)

# %% [markdown]
# # notebook 환경에서 '한글' 글꼴 문제

# %%
s4 = pd.Series(np.random.rand(10), index=list("가나다라마바사아자차"))
s4
# Out:
# 가    0.761795
# 나    0.930873
# 다    0.310295
# 라    0.505000
# 마    0.348569
# 바    0.428056
# 사    0.942198
# 아    0.322411
# 자    0.094570
# 차    0.001629
# dtype: float64

# %%
s4.plot()
# Out:
# <Axes: >
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 44032 (\N{HANGUL SYLLABLE GA}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 45796 (\N{HANGUL SYLLABLE DA}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 47560 (\N{HANGUL SYLLABLE MA}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 49324 (\N{HANGUL SYLLABLE SA}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 51088 (\N{HANGUL SYLLABLE JA}) missing from current font.
#   func(*args, **kwargs)
# ...

# %%
# 한글 폰트 생성 : Colab 환경

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# fonts-nanum is already the newest version (20200506-1).
# 0 upgraded, 0 newly installed, 0 to remove and 38 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 12 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# ...

# %%
plt.rc('font', family='NanumBarunGothic')

# %%
# 이후 Colab 에서 '세션 다시 시작 및 모두 실행' 해야 적용

# %%
s4.plot()
# Out:
# <Axes: >

# %% [markdown]
# # figure, subplot
# - figure(그림)
# - subplot(그림 안의 공간)
#
# ![a](https://matplotlib.org/stable/_images/anatomy.png)

# %%
fig = plt.figure()  #Figure() 객체 생성
fig

# %% [markdown]
# ## add_subplot()
# 그래프의그림공간 추가

# %%
ax1 = fig.add_subplot(2, 2, 1)  # figure 안에 2 x 2 그림공간 생성, 그 중에서 1 번째 리턴
type(ax1) # Axes 객체 생성 ('subplot' 이라고도 함.)
# Out:
# matplotlib.axes._axes.Axes

# %%
ax4 = fig.add_subplot(2, 2, 4)  # 4번째 리턴

# %%
fig

# %%
# plt.subplots(row, col) 사용\
fig, (ax1, ax2, ax3) = plt.subplots(1, 3)

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2)

# %% [markdown]
# # 타이틀 변경

# %%
# 1. plt.title

# 2. ax.set_title(), .get_title()

# %%
ax1.set_title('1st graph')
ax4.set_title('4th graph')

fig

# %%
fig = plt.figure()

ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)

ax1.hist(np.random.randn(100), bins = 20)
ax2.plot(np.random.randn(50).cumsum())
ax3.scatter(np.arange(30), np.arange(30) + 3 * np.random.randn(30))
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
fig, axes = plt.subplots(2, 3)

# %%
axes
# Out:
# array([[<Axes: >, <Axes: >, <Axes: >],
#        [<Axes: >, <Axes: >, <Axes: >]], dtype=object)

# %%
axes[0, 2].plot(np.random.randn(50).cumsum())
axes[1, 1].scatter(np.arange(30), np.arange(30) + 3 * np.random.randn(30))

fig

# %%
# 1. pandas 객체에서 직접 plot() 호출

s = pd.Series(np.random.randn(10).cumsum(), index=np.arange(0, 100, 10))
s.plot()
# Out:
# <Axes: >
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# 2  pyplot의 plot() 사용

plt.plot((1,2))

# %%
# 3. figure의 subplot 사용
fig = plt.figure()
ax1 = fig.add_subplot(1, 1, 1)
ax1.plot(s)

# %%
# 1. plt module(matplotlib.pyplot) API
#       `plt.plot(...)`, `plt.title(...)`    <-- 거의 대부분 이 함수만 사용할거다.
#       장점: 간결. 간편
#       단점: 복잡한 그래프를 그리는데 한계 있다.

# 2. Figure, Subplot 을 이용해서 직접 그래프를 그리는 방법
#       그래프 는 여러 파트로 구성되어 있는데
#          전체 그림 --> Figure
#          Figure 안의 세부 그림 --> Subplot
#       코드는 좀더 복잡하지만..  (개인적으로 자주 애용)


# 3. Pandas ( pd.Series, pd.DataFrame )
#      Series 와 DataFrame 에선 Figure, Subplot 을 다루고 생성하는 함수들 제공
#
#     Series.________, DataFrame._____________
#     => Figure, Subplot
#
#     그러나, 결국 커스터 마이징을 하려면 2 번 방법을 알아야 함

# %% [markdown]
# # Plot 꾸미기

# %%
plt.plot(np.random.randn(50), color='g', marker='o', linestyle='--')
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# plot 꾸미기 옵션

# color
# 값 색상
# "b" blue
# "g" green
# "r" red
# "c" cyan
# "m" magenta
# "y" yellow
# "k" black
# "w" white

# marker
# 값 마킹
# "." point
# "," pixel
# "o" circle
# "v" triangle_down
# "^" triangle_up
# "<" triangle_left
# ">" triangle_right
# "8" octagon
# "s" square
# "p" pentagon
# "*" star
# "h" hexagon
# "+" plus
# "x" x
# "D" diamond

# line style
# 값 라인 스타일
# "-" solid line
# "--" dashed line
# "-." dash-dotted line
# ":" dotted line
# "None" draw nothing

# %%
plt.plot(np.random.randn(50), 'k.-')
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
data = pd.Series(np.random.rand(16), index=list('abcdefghijklmnop'))
data
# Out:
# a    0.037714
# b    0.272668
# c    0.354040
# d    0.682073
# e    0.126598
# f    0.420974
# g    0.313822
# h    0.999639
# i    0.272112
# j    0.136839
# k    0.596631
# l    0.740689
# m    0.851444
# n    0.504295
# o    0.222148
# p    0.473871
# dtype: float64

# %%
data.plot(kind='bar', color='k', alpha=0.7)
# Out:
# <Axes: >

# %%
data.plot(kind='barh', color='g', alpha=0.5)
# Out:
# <Axes: >

# %%
# pandas의 plot() 함수로 그릴 때, figure의 subplot 을 지정하려면 ax= 속성에 지정
fig, axes = plt.subplots(2, 1)
data.plot(kind = 'bar', ax=axes[0], color='k', alpha=0.7)
# Out:
# <Axes: >

# %% [markdown]
# # tick 눈금

# %%
fig, ax = plt.subplots(1, 1)
ax.plot(np.random.randn(1000).cumsum())
# ax.set_xticks([0, 250, 500, 750, 1000])
ax.set_xticks(np.arange(0, 1001, 250))

# %%
# figure size( 최초에 주어져야 한다)
fig, ax = plt.subplots(1, 1, figsize=(8, 8))
ax.plot(np.random.randn(1000).cumsum())
ax.set_xticks(np.arange(0, 1001, 250))

# 눈금의 문자
ax.set_xticklabels(['홍','길','덩','나','무']
                   ,rotation=30, fontsize=20
                   )

#제목
ax.set_title('홍길동')

# x/y 축 라벨
ax.set_xlabel('stages')
ax.set_ylabel('values')

#눈금
ax.grid(True)
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# # 그래프(figure) -> 이미지 저장하기

# %%
import os

# %%
dataset_dir = r'/content/drive/MyDrive/Py19.이종현/dataset'
filepath = os.path.join(dataset_dir, 'figimage1.png')
filepath
# Out:
# '/content/drive/MyDrive/Py19.이종현/dataset/figimage1.png'

# %%
fig.savefig(filepath)
# Out:
# <ipython-input-135-ff036507d68e>:1: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.savefig(filepath)

# %%
fig.savefig(os.path.join(dataset_dir, 'figimage2.png'), dpi=200)
# Out:
# <ipython-input-136-a8eb23cfe4be>:1: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.savefig(os.path.join(dataset_dir, 'figimage2.png'), dpi=200)

# %%
fig.savefig(os.path.join(dataset_dir, 'figimage3.svg'))
fig.savefig(os.path.join(dataset_dir, 'figimage4.pdf'))
# Out:
# <ipython-input-137-5c389a6a5ca1>:1: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.savefig(os.path.join(dataset_dir, 'figimage3.svg'))
# <ipython-input-137-5c389a6a5ca1>:2: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.savefig(os.path.join(dataset_dir, 'figimage4.pdf'))

# %% [markdown]
# # numpy 와 Image 다루기

# %%
from IPython.display import Image

# %%
img_path = os.path.join(dataset_dir, 'cat.jpg')
Image(img_path)

# %%
arr = plt.imread(img_path)
arr
# Out:
# array([[[175, 216, 234],
#         [175, 216, 234],
#         [175, 216, 234],
#         ...,
#         [163, 208, 229],
#         [163, 208, 229],
#         [163, 208, 229]],
#
#        [[175, 216, 234],
#         [175, 216, 234],
#         [175, 216, 234],
#         ...,
#         [163, 208, 229],
#         [163, 208, 229],
#         [163, 208, 229]],
#
#        [[175, 216, 234],
#         [175, 216, 234],
#         [175, 216, 234],
#         ...,
#         [163, 208, 229],
#         [163, 208, 229],
#         [163, 208, 229]],
#
#        ...,
#
#        [[177, 216, 233],
#         [177, 216, 233],
#         [177, 216, 233],
#         ...,
#         [165, 206, 228],
#         [165, 206, 228],
#         [165, 206, 228]],
#
#        [[177, 216, 233],
#         [177, 216, 233],
#         [177, 216, 233],
#         ...,
#         [165, 206, 228],
#         [165, 206, 228],
#         [165, 206, 228]],
#
#        [[177, 216, 233],
#         [177, 216, 233],
#         [177, 216, 233],
# ...

# %%
# 이미지 크기
arr.shape

# (height, width, pixel)   # 순서 주의
# Out:
# (183, 275, 3)

# %%
arr[0]  # 이미지의 첫번째 row
# Out:
# array([[175, 216, 234],
#        [175, 216, 234],
#        [175, 216, 234],
#        [175, 216, 234],
#        [175, 216, 234],
#        [175, 216, 234],
#        [175, 216, 234],
#        [175, 216, 234],
#        [176, 217, 235],
#        [176, 217, 235],
#        [176, 217, 235],
#        [176, 217, 235],
#        [176, 217, 235],
#        [176, 217, 235],
#        [176, 217, 235],
#        [176, 217, 235],
#        [176, 217, 235],
#        [176, 217, 235],
#        [176, 217, 235],
#        [176, 217, 235],
#        [176, 217, 235],
#        [176, 217, 235],
#        [176, 217, 235],
#        [176, 217, 235],
#        [176, 217, 235],
#        [176, 217, 235],
#        [176, 217, 235],
#        [176, 217, 235],
#        [176, 217, 235],
#        [176, 217, 235],
#        [176, 217, 235],
#        [176, 217, 235],
#        [176, 217, 235],
#        [176, 217, 235],
#        [176, 217, 235],
#        [176, 217, 235],
#        [176, 217, 235],
#        [176, 217, 235],
# ...

# %%
arr[0, 5]  #row:0,  col: 5 의 pixel

# [red, green, blue]
# Out:
# array([175, 216, 234], dtype=uint8)

# %%
arr[0, 5, 1]   #green channel
# Out:
# 216

# %% [markdown]
# # 이미지의 slicing

# %%
plt.imshow(arr)

# %%
plt.imshow(arr[100:200, 50:150])

# %% [markdown]
# # 좌우/상하 반전

# %%
arr[::-1, ::-1]
# Out:
# array([[[165, 206, 228],
#         [165, 206, 228],
#         [165, 206, 228],
#         ...,
#         [177, 216, 233],
#         [177, 216, 233],
#         [177, 216, 233]],
#
#        [[165, 206, 228],
#         [165, 206, 228],
#         [165, 206, 228],
#         ...,
#         [177, 216, 233],
#         [177, 216, 233],
#         [177, 216, 233]],
#
#        [[165, 206, 228],
#         [165, 206, 228],
#         [165, 206, 228],
#         ...,
#         [177, 216, 233],
#         [177, 216, 233],
#         [177, 216, 233]],
#
#        ...,
#
#        [[163, 208, 229],
#         [163, 208, 229],
#         [163, 208, 229],
#         ...,
#         [175, 216, 234],
#         [175, 216, 234],
#         [175, 216, 234]],
#
#        [[163, 208, 229],
#         [163, 208, 229],
#         [163, 208, 229],
#         ...,
#         [175, 216, 234],
#         [175, 216, 234],
#         [175, 216, 234]],
#
#        [[163, 208, 229],
#         [163, 208, 229],
#         [163, 208, 229],
# ...

# %% [markdown]
# ## 색상 gray scale 변경해보기

# %%
arr.shape
# Out:
# (183, 275, 3)

# %%
# red 만 추출
r = arr[:, :, 0]
r
# Out:
# array([[175, 175, 175, ..., 163, 163, 163],
#        [175, 175, 175, ..., 163, 163, 163],
#        [175, 175, 175, ..., 163, 163, 163],
#        ...,
#        [177, 177, 177, ..., 165, 165, 165],
#        [177, 177, 177, ..., 165, 165, 165],
#        [177, 177, 177, ..., 165, 165, 165]], dtype=uint8)

# %%
r.shape
# Out:
# (183, 275)

# %%
#     # image_arr.shape == (1200, 1600, 3)
#     r = image_arr[:, :, 0]    # r.shape = (1200, 1600)
#     g = image_arr[:, :, 1]
#     b = image_arr[:, :, 2]

# r, g, b  '3개의 색값'을 사용하여 '한개의 색' 로 변경하는 공식 예
#         r * 0.299 + g * 0.587 + b * 0.114   (green 값 강조)


# 즉
# (1200 x 1600 x 3) ...→ ... ( 1200 x 1600 ) 으로 변화시키면 된다.

# 이는 다음과 같은 행렬 곱을 하면 된다.
# (1200 x 1600 x 3) x ( 3 x 1 ) => 1200 x 1600

# %%
def color_to_grayscale(image_arr):
  return np.dot(
      image_arr,  #(h * w * 3:rgb)
      np.array([0.299, 0.587, 0.114])  #(3 x 1) 행렬
  )

# %%
plt.imshow(color_to_grayscale(arr))

# %%
color_to_grayscale(arr)
# Out:
# array([[205.793, 205.793, 205.793, ..., 196.939, 196.939, 196.939],
#        [205.793, 205.793, 205.793, ..., 196.939, 196.939, 196.939],
#        [205.793, 205.793, 205.793, ..., 196.939, 196.939, 196.939],
#        ...,
#        [206.277, 206.277, 206.277, ..., 196.249, 196.249, 196.249],
#        [206.277, 206.277, 206.277, ..., 196.249, 196.249, 196.249],
#        [206.277, 206.277, 206.277, ..., 196.249, 196.249, 196.249]])

# %% [markdown]
# # Seaborn 패키지
# ![](https://seaborn.pydata.org/_static/logo-wide-lightbg.svg)
#
# Seaborn은 matplotlib 패키지를 기반으로 하여 보다 편하게 통계를 시각화할 수 있는 도구입니다. 일반적으로 데이터 사이언스에서 사용하는 대부분의 그래프를 지원합니다.
#
# 공식: https://seaborn.pydata.org/
#
# 갤러리: https://seaborn.pydata.org/examples/index.html

# %%
col_id = pd.Series(data=[5, 14, 21, 25])
col_team = pd.Series(data=['A', 'A', 'B', 'B'])
col_name = pd.Series(data=['홍승현', '변유송', '황희지', '이주홍'])
col_score = pd.Series(data=[100, 95, 60, 80])

df = pd.DataFrame(data={'Id': col_id,
                        'Team': col_team,
                        'Name': col_name,
                        'Score': col_score})
df.set_index('Id', inplace=True)
df
# Out:
#    Team Name  Score
# Id
# 5     A  홍승현    100
# 14    A  변유송     95
# 21    B  황희지     60
# 25    B  이주홍     80

# %%
df['Score'].hist()
# Out:
# <Axes: >

# %%
import seaborn as sns

# %%
sns.histplot(x='Score', data=df)
# Out:
# <Axes: xlabel='Score', ylabel='Count'>

# %%
sns.histplot(x='Score', data=df, bins=20)
# Out:
# <Axes: xlabel='Score', ylabel='Count'>

# %%
sns.histplot(x='Score', data=df, bins=2)
# Out:
# <Axes: xlabel='Score', ylabel='Count'>

# %%
df
# Out:
#    Team Name  Score
# Id
# 5     A  홍승현    100
# 14    A  변유송     95
# 21    B  황희지     60
# 25    B  이주홍     80

# %%
sns.histplot(x='Score', data=df, hue='Team')
# Out:
# <Axes: xlabel='Score', ylabel='Count'>

# %%
sns.boxplot(y='Score', x='Team', data=df)
# Out:
# <Axes: xlabel='Team', ylabel='Score'>

# %% [markdown]
# # wordcloud
#
# <img src='https://amueller.github.io/word_cloud/_images/a_new_hope.png' style='width:400px; height:auto'><br>
#
# 공식 : https://amueller.github.io/word_cloud/index.html
#
# 설지 : > **pip install wordcloud**
#
# wordcloud 라이브러리는 matplotlib 과 함께 사용됨

# %%
import wordcloud

# %%
wordcloud.__version__
# Out:
# '1.9.3'

# %%
words = {
    'Python' : 10,
    'Java' : 5,
    'C' : 7,
    'C++': 9,
    'JavaScript': 8
}

# %%
wc = wordcloud.WordCloud()
wc

# %%
cloud = wc.generate_from_frequencies(words)
cloud

# %%
plt.imshow(cloud)
